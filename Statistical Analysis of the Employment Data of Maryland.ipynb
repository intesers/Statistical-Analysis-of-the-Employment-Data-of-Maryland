# %%
#Importing Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) #Customizes the size of the plot.

# %%
#read data

df = pd.read_csv(r'E:\project\Python\Projects\Maryland\Combined.csv')

df.head()
# Out:
#                    geo  Total Population, 2018  Labor Force  Unemployment  \
# 0      Allegany County                   70975        31984          1764
# 1  Anne Arundel County                  576031       309603         10343
# 2       Baltimore City                  602495       289758         16454
# 3     Baltimore County                  828431       450366         18202
# 4       Calvert County                   92003        49121          1739
#
#    Median Household Income ($ Dollars)  \
# 0                                43535
# 1                                97051
# 2                                50501
# 3                                75836
# 4                               106270
#
#    Median Sale Price of a Home ($ Dollars) Local Personal Income Tax Rate (%)  \
# 0                                    90829                              3.05%
# 1                                   338287                               2.81
# 2                                   139723                                3.2
# 3                                   238426                                3.2
# 4                                   318471                                  3
#
#    Bachelor's Degree Attainment (%)  Average Travel Time to Work (Minutes)
# 0                              18.3                                   21.3
# 1                              40.9                                   30.7
# 2                              31.2                                   31.0
# 3                              38.6                                   29.6
# 4                              31.1                                   41.7

# %%
#checking missing data

df.isna().sum()
# Out:
# geo                                        0
# Total Population, 2018                     0
# Labor Force                                0
# Unemployment                               0
# Median Household Income ($ Dollars)        0
# Median Sale Price of a Home ($ Dollars)    0
# Local Personal Income Tax Rate (%)         0
# Bachelor's Degree Attainment (%)           0
# Average Travel Time to Work (Minutes)      0
# dtype: int64

# %%
#drop any duplicates

df.drop_duplicates()
# Out:
#                        geo  Total Population, 2018  Labor Force  Unemployment  \
# 0          Allegany County                   70975        31984          1764
# 1      Anne Arundel County                  576031       309603         10343
# 2           Baltimore City                  602495       289758         16454
# 3         Baltimore County                  828431       450366         18202
# 4           Calvert County                   92003        49121          1739
# 5          Caroline County                   33304        18028           688
# 6           Carroll County                  168429        94339          3062
# 7             Cecil County                  102826        52632          2317
# 8           Charles County                  161503        85104          3299
# 9        Dorchester County                   31998        15347           799
# 10        Frederick County                  255648       130831          4598
# 11          Garrett County                   29163        15410           737
# 12          Harford County                  253956       138162          5005
# 13           Howard County                  323196       183889          5529
# 14             Kent County                   19383        10254           444
# 15       Montgomery County                 1052567       554989         17560
# 16  Prince George's County                  909308       504423         20573
# 17     Queen Anne's County                   50251        27379           917
# 18       St. Mary's County                  112664        55295          2102
# 19         Somerset County                   25675         9353           644
# 20           Talbot County                   36968        19562           733
# 21       Washington County                  150926        74742          3249
# 22         Wicomico County                  103195        51041          2676
# 23        Worcester County                   51823        25525          2050
#
#     Median Household Income ($ Dollars)  \
# 0                                 43535
# 1                                 97051
# 2                                 50501
# 3                                 75836
# 4                                106270
# 5                                 56627
# 6                                 95956
# 7                                 72739
# 8                                 92616
# 9                                 48682
# 10                                95196
# 11                                49147
# 12                                87959
# 13                               116719
# 14                                55514
# 15                               107758
# 16                                82445
# 17                                93751
# 18                                89964
# 19                                42098
# 20                                64245
# 21                                62556
# 22                                54313
# 23                                59266
#
#     Median Sale Price of a Home ($ Dollars)  \
# 0                                     90829
# 1                                    338287
# 2                                    139723
# 3                                    238426
# 4                                    318471
# 5                                    181574
# 6                                    316458
# 7                                    225308
# 8                                    295354
# 9                                    169719
# 10                                   311525
# 11                                   245142
# 12                                   247158
# 13                                   406617
# 14                                   223917
# 15                                   438521
# 16                                   286098
# 17                                   333504
# 18                                   277790
# 19                                   117833
# 20                                   303771
# 21                                   190088
# 22                                   145261
# 23                                   251338
#
#    Local Personal Income Tax Rate (%)  Bachelor's Degree Attainment (%)  \
# 0                               3.05%                              18.3
# 1                                2.81                              40.9
# 2                                 3.2                              31.2
# 3                                 3.2                              38.6
# 4                                   3                              31.1
# 5                                 3.2                              16.9
# 6                                3.03                              35.6
# 7                                   3                              22.8
# 8                                3.03                              28.9
# 9                                 3.2                              20.8
# 10                               2.96                              40.6
# 11                               2.65                              20.1
# 12                               3.06                              35.8
# 13                                3.2                              61.4
# 14                                3.2                              34.2
# 15                                3.2                              59.0
# 16                                3.2                              32.7
# 17                                3.2                              34.9
# 18                               3.17                              31.5
# 19                                3.2                              15.7
# 20                                2.4                              38.6
# 21                                3.2                              21.4
# 22                                3.2                              26.8
# 23                               2.25                              30.4
#
#     Average Travel Time to Work (Minutes)
# 0                                    21.3
# 1                                    30.7
# 2                                    31.0
# 3                                    29.6
# 4                                    41.7
# 5                                    32.9
# 6                                    35.9
# 7                                    29.6
# 8                                    44.4
# 9                                    27.0
# 10                                   35.2
# 11                                   24.5
# 12                                   31.8
# 13                                   31.3
# 14                                   26.4
# 15                                   34.6
# 16                                   37.0
# 17                                   37.0
# 18                                   30.9
# 19                                   24.8
# 20                                   28.1
# 21                                   29.7
# 22                                   22.0
# 23                                   25.1

# %%
#scatter plot between level of education and median household income

plt.scatter(x = df["Bachelor's Degree Attainment (%)"], y = df["Median Household Income ($ Dollars)"])
plt.title('Relationship Between Level of Education and Income')
plt.xlabel("Bachelors Degree")
plt.ylabel('Median Household Income')
plt.show()

# %%
#Plotting a regression plot
sns.set_theme(color_codes=True)
reg = sns.regplot(x="Bachelor's Degree Attainment (%)", y="Median Household Income ($ Dollars)", data=df)
reg.set(xlabel = "Bachelors Degree", ylabel = "Median Household Income")
reg.set_title("Relationship Between Level of Education and Income")
# Out:
# Text(0.5, 1.0, 'Relationship Between Level of Education and Income')

# %% [markdown]
# There is a positive relation between education and the income. The counties which have higher level of Bachelor's degree attainment has a higher median household income as well.

# %%
#Relationship between education and unemployment

reg2 = sns.regplot(x="Bachelor's Degree Attainment (%)", y="Unemployment", data=df)
reg2.set(xlabel = "Bachelors Degree", ylabel = "Unemployment")
reg2.set_title("Relationship Between Level of Education and Unemployment")
# Out:
# Text(0.5, 1.0, 'Relationship Between Level of Education and Unemployment')

# %% [markdown]
# From a general perspective, this is unlikely that there would be a positive relationship between Education and Unemployment. This result is most likely due to the absolute values of the unemployed people in the larger counties of Maryland. As counties with higher population would have relatively higher number of unemployed people as well. So, it would be more appropiate to test this using the percentage of unemployed people rather than plotting the absolute values.

# %%
#Calculating the percentage of Unemployemnt

df["Unemployment(%)"] = (df["Unemployment"]/df["Total Population, 2018"])*100

df.head()
# Out:
#                    geo  Total Population, 2018  Labor Force  Unemployment  \
# 0      Allegany County                   70975        31984          1764
# 1  Anne Arundel County                  576031       309603         10343
# 2       Baltimore City                  602495       289758         16454
# 3     Baltimore County                  828431       450366         18202
# 4       Calvert County                   92003        49121          1739
#
#    Median Household Income ($ Dollars)  \
# 0                                43535
# 1                                97051
# 2                                50501
# 3                                75836
# 4                               106270
#
#    Median Sale Price of a Home ($ Dollars) Local Personal Income Tax Rate (%)  \
# 0                                    90829                              3.05%
# 1                                   338287                               2.81
# 2                                   139723                                3.2
# 3                                   238426                                3.2
# 4                                   318471                                  3
#
#    Bachelor's Degree Attainment (%)  Average Travel Time to Work (Minutes)  \
# 0                              18.3                                   21.3
# 1                              40.9                                   30.7
# 2                              31.2                                   31.0
# 3                              38.6                                   29.6
# 4                              31.1                                   41.7
#
#    Unemployment(%)
# 0         2.485382
# 1         1.795563
# 2         2.730977
# 3         2.197165
# 4         1.890156

# %%
#Testing out the relationship between education and percentage of unemployment again

reg3 = sns.regplot(x="Bachelor's Degree Attainment (%)", y="Unemployment(%)", data=df, scatter_kws={'color': '#e85a5a'}, line_kws= {'color': '#e85a5a'})
reg3.set(xlabel = "Bachelors Degree", ylabel = "Unemployment")
reg3.set_title("Relationship Between Level of Education and Unemployment")
# Out:
# Text(0.5, 1.0, 'Relationship Between Level of Education and Unemployment')

# %% [markdown]
# As we can see, as more people attained Bachelor's degree, unemployed rate continued to drop.

# %%
#Looking at correaltion

corr_matrix= df.corr()

corr_matrix
# Out:
#                                          Total Population, 2018  Labor Force  \
# Total Population, 2018                                 1.000000     0.998585
# Labor Force                                            0.998585     1.000000
# Unemployment                                           0.976217     0.971765
# Median Household Income ($ Dollars)                    0.388203     0.405422
# Median Sale Price of a Home ($ Dollars)                0.388325     0.407032
# Bachelor's Degree Attainment (%)                       0.570319     0.578094
# Average Travel Time to Work (Minutes)                  0.271397     0.279561
#
#                                          Unemployment  \
# Total Population, 2018                       0.976217
# Labor Force                                  0.971765
# Unemployment                                 1.000000
# Median Household Income ($ Dollars)          0.270882
# Median Sale Price of a Home ($ Dollars)      0.251946
# Bachelor's Degree Attainment (%)             0.463160
# Average Travel Time to Work (Minutes)        0.235826
#
#                                          Median Household Income ($ Dollars)  \
# Total Population, 2018                                              0.388203
# Labor Force                                                         0.405422
# Unemployment                                                        0.270882
# Median Household Income ($ Dollars)                                 1.000000
# Median Sale Price of a Home ($ Dollars)                             0.890269
# Bachelor's Degree Attainment (%)                                    0.764109
# Average Travel Time to Work (Minutes)                               0.731712
#
#                                          Median Sale Price of a Home ($ Dollars)  \
# Total Population, 2018                                                  0.388325
# Labor Force                                                             0.407032
# Unemployment                                                            0.251946
# Median Household Income ($ Dollars)                                     0.890269
# Median Sale Price of a Home ($ Dollars)                                 1.000000
# Bachelor's Degree Attainment (%)                                        0.831505
# Average Travel Time to Work (Minutes)                                   0.597889
#
#                                          Bachelor's Degree Attainment (%)  \
# Total Population, 2018                                           0.570319
# Labor Force                                                      0.578094
# Unemployment                                                     0.463160
# Median Household Income ($ Dollars)                              0.764109
# Median Sale Price of a Home ($ Dollars)                          0.831505
# Bachelor's Degree Attainment (%)                                 1.000000
# Average Travel Time to Work (Minutes)                            0.327959
#
#                                          Average Travel Time to Work (Minutes)
# Total Population, 2018                                                0.271397
# Labor Force                                                           0.279561
# Unemployment                                                          0.235826
# Median Household Income ($ Dollars)                                   0.731712
# Median Sale Price of a Home ($ Dollars)                               0.597889
# Bachelor's Degree Attainment (%)                                      0.327959
# Average Travel Time to Work (Minutes)                                 1.000000

# %%
#Generating a heatmap for the correlation

sns.heatmap(corr_matrix, annot= True, cmap = "Blues")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Aside from the positve correlation between Bachelors degree attainment and Median household income, there is also a strong positive correlation between median sale price of homes and education, suggesting that with the rise in education, people tend to live a relatively more luxurious life.
#
# Also, there is a stong positive correlation between the Median Household income and Average Travel Time to Work, which could suggest that people of Maryland are commuting far distances for better paying jobs.
